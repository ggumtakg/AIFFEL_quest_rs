# %%
import tensorflow as tf
from tensorflow import keras

class MyMetric(keras.metrics.Metric):

    def __init__(self, name="r2_score", **kwargs):
        super().__init__(name=name, **kwargs)
        self.sse_sum = self.add_weight(name="sse_sum", initializer="zeros")
        self.tss_sum = self.add_weight(name="tss_sum", initializer="zeros")
        self.total_samples = self.add_weight(
            name="total_samples", initializer="zeros", dtype="int32")

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, y_pred.dtype)
        residuals = y_true - y_pred
        sse = tf.reduce_sum(tf.square(residuals))
        self.sse_sum.assign_add(sse)

        mean_y_true = tf.reduce_mean(y_true)
        total_deviation = y_true - mean_y_true
        tss = tf.reduce_sum(tf.square(total_deviation))
        self.tss_sum.assign_add(tss)

        num_samples = tf.shape(y_pred)[0]
        self.total_samples.assign_add(num_samples)

    def result(self):
        r2_score = 1 - (self.sse_sum / (self.tss_sum + tf.keras.backend.epsilon()))
        return r2_score

    def reset_state(self):
        self.sse_sum.assign(0.)
        self.tss_sum.assign(0.)
        self.total_samples.assign(0)

# %%
from tensorflow.keras.datasets import imdb
import numpy as np
from tensorflow.keras import layers
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results
train_data = vectorize_sequences(train_data)

model = keras.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy", MyMetric()])
history_original = model.fit(train_data, train_labels, epochs=20, batch_size=128, validation_split=0.4)
# Out:
# Epoch 1/20
# 118/118 [==============================] - 9s 54ms/step - loss: 0.3849 - accuracy: 0.8459 - r2_score: 0.5171 - val_loss: 0.3056 - val_accuracy: 0.8760 - val_r2_score: 0.6308
# Epoch 2/20
# 118/118 [==============================] - 2s 16ms/step - loss: 0.2066 - accuracy: 0.9230 - r2_score: 0.7615 - val_loss: 0.2951 - val_accuracy: 0.8836 - val_r2_score: 0.6501
# Epoch 3/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.1517 - accuracy: 0.9450 - r2_score: 0.8298 - val_loss: 0.3024 - val_accuracy: 0.8854 - val_r2_score: 0.6542
# Epoch 4/20
# 118/118 [==============================] - 2s 16ms/step - loss: 0.1141 - accuracy: 0.9601 - r2_score: 0.8749 - val_loss: 0.3383 - val_accuracy: 0.8815 - val_r2_score: 0.6329
# Epoch 5/20
# 118/118 [==============================] - 2s 13ms/step - loss: 0.0847 - accuracy: 0.9713 - r2_score: 0.9088 - val_loss: 0.4144 - val_accuracy: 0.8724 - val_r2_score: 0.5917
# Epoch 6/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0648 - accuracy: 0.9789 - r2_score: 0.9316 - val_loss: 0.4331 - val_accuracy: 0.8765 - val_r2_score: 0.5944
# Epoch 7/20
# 118/118 [==============================] - 2s 14ms/step - loss: 0.0456 - accuracy: 0.9852 - r2_score: 0.9526 - val_loss: 0.5354 - val_accuracy: 0.8673 - val_r2_score: 0.5512
# Epoch 8/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0309 - accuracy: 0.9903 - r2_score: 0.9688 - val_loss: 0.7128 - val_accuracy: 0.8501 - val_r2_score: 0.4846
# Epoch 9/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0204 - accuracy: 0.9943 - r2_score: 0.9802 - val_loss: 0.6705 - val_accuracy: 0.8677 - val_r2_score: 0.5400
# Epoch 10/20
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0119 - accuracy: 0.9965 - r2_score: 0.9891 - val_loss: 0.7635 - val_accuracy: 0.8655 - val_r2_score: 0.5282
# Epoch 11/20
# 118/118 [==============================] - 2s 15ms/step - loss: 0.0067 - accuracy: 0.9983 - r2_score: 0.9939 - val_loss: 0.9260 - val_accuracy: 0.8600 - val_r2_score: 0.5011
# Epoch 12/20
# 118/118 [==============================] - 2s 17ms/step - loss: 0.0037 - accuracy: 0.9991 - r2_score: 0.9969 - val_loss: 1.0170 - val_accuracy: 0.8644 - val_r2_score: 0.5074
# Epoch 13/20
# 118/118 [==============================] - 2s 16ms/step - loss: 0.0020 - accuracy: 0.9995 - r2_score: 0.9985 - val_loss: 1.1431 - val_accuracy: 0.8610 - val_r2_score: 0.4941
# Epoch 14/20
# 118/118 [==============================] - 2s 17ms/step - loss: 9.6551e-04 - accuracy: 0.9999 - r2_score: 0.9994 - val_loss: 1.2779 - val_accuracy: 0.8605 - val_r2_score: 0.4852
# Epoch 15/20
# 118/118 [==============================] - 2s 17ms/step - loss: 4.5039e-04 - accuracy: 0.9999 - r2_score: 0.9997 - val_loss: 1.4279 - val_accuracy: 0.8607 - val_r2_score: 0.4796
# Epoch 16/20
# 118/118 [==============================] - 2s 16ms/step - loss: 3.3129e-04 - accuracy: 0.9999 - r2_score: 0.9998 - val_loss: 1.5422 - val_accuracy: 0.8602 - val_r2_score: 0.4712
# Epoch 17/20
# 118/118 [==============================] - 2s 15ms/step - loss: 1.4791e-04 - accuracy: 1.0000 - r2_score: 0.9999 - val_loss: 1.6783 - val_accuracy: 0.8586 - val_r2_score: 0.4706
# Epoch 18/20
# 118/118 [==============================] - 2s 17ms/step - loss: 1.1234e-04 - accuracy: 1.0000 - r2_score: 0.9999 - val_loss: 1.7842 - val_accuracy: 0.8591 - val_r2_score: 0.4671
# Epoch 19/20
# 118/118 [==============================] - 2s 17ms/step - loss: 7.2524e-05 - accuracy: 1.0000 - r2_score: 0.9999 - val_loss: 1.8941 - val_accuracy: 0.8579 - val_r2_score: 0.4596
# Epoch 20/20
# 118/118 [==============================] - 2s 17ms/step - loss: 1.6753e-04 - accuracy: 0.9999 - r2_score: 0.9998 - val_loss: 1.9632 - val_accuracy: 0.8591 - val_r2_score: 0.4646
